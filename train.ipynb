# %% [markdown]
# # 데이터 준비

# %%
from utils import *

# %% [markdown]
# ## 베이스라인

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler,StandardScaler
from sklearn.linear_model import LinearRegression

# 데이터 불러오기
raw_df = pd.read_csv('./전처리_완료/12_22아파트매매.csv')
df = preprocess(raw_df)
df.sample(1)
# Out:
#        거래금액  건축년도     년  법정동  아파트  월   일   전용면적   층        계약일
# 5568  77000    16  2013  청담동  신동아  9  16  84.94  13 2013-09-16

# %%
baseline = onehotencoding(scaling(df))
# baseline = scaling(df)
baseline
# Out:
#          거래금액      건축년도     년          아파트   월   일      전용면적         층
# 0       68000  0.163265  2012        역삼래미안   1   2  0.114745  0.115942  \
# 1       22950  0.224490  2012        대우디오빌   1   2  0.043496  0.275362
# 2       44500  0.183673  2012      브라운스톤역삼   1   4  0.116103  0.130435
# 3       99000  0.142857  2012       역삼푸르지오   1   7  0.176628  0.173913
# 4       49500  0.142857  2012     역삼디오슈페리움   1   7  0.175246  0.260870
# ...       ...       ...   ...          ...  ..  ..       ...       ...
# 49314   95000  0.632653  2022          신동아  12  10  0.066494  0.202899
# 49315  260000  0.489796  2022       대림아크로빌  12   9  0.400648  0.333333
# 49316  260000  0.489796  2022       대림아크로빌  12  15  0.389033  0.463768
# 49317   96500  0.408163  2022        대명비발디  12  17  0.158920  0.101449
# 49318  183000  0.265306  2022  도곡지웰카운티101동  12  17  0.230484  0.028986
#
#             계약일  법정동_개포동  ...  법정동_삼성동  법정동_세곡동  법정동_수서동  법정동_신사동  법정동_압구정동
# ...

# %% [markdown]
# ## 경제

# %%
economic = onehotencoding(scaling(*economic_merge_data(df)))
# economic = scaling(*economic_merge_data(df))
economic
# Out:
# /home/work/mC2E2/datamining
# 기준금리_start
# 기준금리_end
# GDP_start
# GDP_end
#          거래금액      건축년도     년          아파트   월   일      전용면적         층
# 0       68000  0.163265  2012        역삼래미안   1   2  0.114745  0.115942  \
# 1       22950  0.224490  2012        대우디오빌   1   2  0.043496  0.275362
# 2       44500  0.183673  2012      브라운스톤역삼   1   4  0.116103  0.130435
# 3       99000  0.142857  2012       역삼푸르지오   1   7  0.176628  0.173913
# 4       49500  0.142857  2012     역삼디오슈페리움   1   7  0.175246  0.260870
# ...       ...       ...   ...          ...  ..  ..       ...       ...
# 49314   95000  0.632653  2022          신동아  12  10  0.066494  0.202899
# 49315  260000  0.489796  2022       대림아크로빌  12   9  0.400648  0.333333
# 49316  260000  0.489796  2022       대림아크로빌  12  15  0.389033  0.463768
# 49317   96500  0.408163  2022        대명비발디  12  17  0.158920  0.101449
# 49318  183000  0.265306  2022  도곡지웰카운티101동  12  17  0.230484  0.028986
#
# ...

# %% [markdown]
# ## 사회

# %%
social = onehotencoding(scaling(*social_merge_data(df)))
# social = scaling(*social_merge_data(df))
social
# Out:
# 공원수_start
# 공원수_end
# 인구밀도_start
# 인구밀도_end
#          거래금액      건축년도     년          아파트   월   일      전용면적         층
# 0       68000  0.163265  2012        역삼래미안   1   2  0.114745  0.115942  \
# 1       22950  0.224490  2012        대우디오빌   1   2  0.043496  0.275362
# 2       44500  0.183673  2012      브라운스톤역삼   1   4  0.116103  0.130435
# 3       99000  0.142857  2012       역삼푸르지오   1   7  0.176628  0.173913
# 4       49500  0.142857  2012     역삼디오슈페리움   1   7  0.175246  0.260870
# ...       ...       ...   ...          ...  ..  ..       ...       ...
# 49314   95000  0.632653  2022          신동아  12  10  0.066494  0.202899
# 49315  260000  0.489796  2022       대림아크로빌  12   9  0.400648  0.333333
# 49316  260000  0.489796  2022       대림아크로빌  12  15  0.389033  0.463768
# 49317   96500  0.408163  2022        대명비발디  12  17  0.158920  0.101449
# 49318  183000  0.265306  2022  도곡지웰카운티101동  12  17  0.230484  0.028986
#
# ...

# %% [markdown]
# ## 부동산

# %%
bodong = onehotencoding(scaling(*bodong_merge_data(df)))
# bodong = scaling(*bodong_merge_data(df))
bodong
# Out:
# 선도50지수_start
# 선도50지수_end
# 전세가격지수_start
# 전세가격지수_end
# 매매가격지수_start
# 매매가격지수_end
#          거래금액      건축년도     년          아파트   월   일      전용면적         층
# 0       68000  0.163265  2012        역삼래미안   1   2  0.114745  0.115942  \
# 1       22950  0.224490  2012        대우디오빌   1   2  0.043496  0.275362
# 2       44500  0.183673  2012      브라운스톤역삼   1   4  0.116103  0.130435
# 3       99000  0.142857  2012       역삼푸르지오   1   7  0.176628  0.173913
# 4       49500  0.142857  2012     역삼디오슈페리움   1   7  0.175246  0.260870
# ...       ...       ...   ...          ...  ..  ..       ...       ...
# 49314   95000  0.632653  2022          신동아  12  10  0.066494  0.202899
# 49315  260000  0.489796  2022       대림아크로빌  12   9  0.400648  0.333333
# 49316  260000  0.489796  2022       대림아크로빌  12  15  0.389033  0.463768
# 49317   96500  0.408163  2022        대명비발디  12  17  0.158920  0.101449
# 49318  183000  0.265306  2022  도곡지웰카운티101동  12  17  0.230484  0.028986
#
# ...

# %% [markdown]
# # 학습 진행

# %%
from trainning import main

# %% [markdown]
# # 베이스라인 결과 분석
#
# 상대적으로 단순한 모델에 해당하는 SVM과 KNN모델은 Feature수에 영향을 받기 때문에 R2 score가 높게 산정되는 것을 알 수 있다.
# 반면 다소 복잡한 모델이라고도 하는 뉴럴네트워크 기반 멀티레이어 퍼셉트론이 상대적으로 어려워 하는 것을 알 수 있다.

# %%
X_train, X_test, y_train, y_test = get_x_y(baseline)
test_name = 'baseline'
main(X_train, X_test, y_train, y_test,test_name)
# Out:
# 1 result baseline predict result with using SVR
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 3
#       1 X_train, X_test, y_train, y_test = get_x_y(baseline)
#       2 test_name = 'baseline'
# ----> 3 main(X_train, X_test, y_train, y_test,test_name)
#
# File ~/mC2E2/datamining/trainning.py:40, in main(X_train, X_test, y_train, y_test, test_name)
#      38     y_pred = model.predict(valid)
#      39     print(f'{i + 1} result {test_name} predict result with using {name}')
# ---> 40     rmse,r2 = regression_results(valid_y,y_pred)
#      41     tmp.append(r2)
#      42 # cv_results = cross_val_score(model, X_train, y_train, cv=tscv, scoring='r2')
#
# NameError: name 'regression_results' is not defined

# %% [markdown]
# ## 경제 결과 분석

# %%
X_train, X_test, y_train, y_test = get_x_y(economic)
test_name = 'economic'
main(X_train, X_test, y_train, y_test,test_name)
# Out:
# 1 result economic predict result with using SVR
# 2 result economic predict result with using SVR
# 3 result economic predict result with using SVR
# r2:  0.7184
# MAE:  0.2386
# MSE:  0.1119
# RMSE:  0.3345
# SVR: 0.725895 (0.005509)
# 1 result economic predict result with using KNN
# 2 result economic predict result with using KNN
# 3 result economic predict result with using KNN
# r2:  0.8102
# MAE:  0.1742
# MSE:  0.0754
# RMSE:  0.2746
# KNN: 0.757306 (0.046418)
# /home/work/.local/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 1 result economic predict result with using NN
# /home/work/.local/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %% [markdown]
# # 사회

# %%
social
# Out:
#          거래금액      건축년도     년          아파트   월   일      전용면적         층
# 0       68000  0.163265  2012        역삼래미안   1   2  0.114745  0.115942  \
# 1       22950  0.224490  2012        대우디오빌   1   2  0.043496  0.275362
# 2       44500  0.183673  2012      브라운스톤역삼   1   4  0.116103  0.130435
# 3       99000  0.142857  2012       역삼푸르지오   1   7  0.176628  0.173913
# 4       49500  0.142857  2012     역삼디오슈페리움   1   7  0.175246  0.260870
# ...       ...       ...   ...          ...  ..  ..       ...       ...
# 49314   95000  0.632653  2022          신동아  12  10  0.066494  0.202899
# 49315  260000  0.489796  2022       대림아크로빌  12   9  0.400648  0.333333
# 49316  260000  0.489796  2022       대림아크로빌  12  15  0.389033  0.463768
# 49317   96500  0.408163  2022        대명비발디  12  17  0.158920  0.101449
# 49318  183000  0.265306  2022  도곡지웰카운티101동  12  17  0.230484  0.028986
#
#             계약일       공원수  ...  법정동_삼성동  법정동_세곡동  법정동_수서동  법정동_신사동  법정동_압구정동
# ...

# %%
X_train, X_test, y_train, y_test = get_x_y(social)
# Spot Check Algorithms
test_name = 'social'
main(X_train, X_test, y_train, y_test,test_name)
# Out:
# 1 result social predict result with using SVR
# 2 result social predict result with using SVR
# 3 result social predict result with using SVR
# r2:  0.6106
# MAE:  0.3103
# MSE:  0.1565
# RMSE:  0.3956
# SVR: 0.616006 (0.003070)
# 1 result social predict result with using KNN
# 2 result social predict result with using KNN
# 3 result social predict result with using KNN
# r2:  0.9056
# MAE:  0.129
# MSE:  0.0379
# RMSE:  0.1948
# KNN: 0.887965 (0.016743)
# /home/work/.local/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 1 result social predict result with using NN
# /home/work/.local/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %% [markdown]
# # 부동산

# %%
bodong
# Out:
#          거래금액      건축년도     년          아파트   월   일      전용면적         층
# 0       68000  0.163265  2012        역삼래미안   1   2  0.114745  0.115942  \
# 1       22950  0.224490  2012        대우디오빌   1   2  0.043496  0.275362
# 2       44500  0.183673  2012      브라운스톤역삼   1   4  0.116103  0.130435
# 3       99000  0.142857  2012       역삼푸르지오   1   7  0.176628  0.173913
# 4       49500  0.142857  2012     역삼디오슈페리움   1   7  0.175246  0.260870
# ...       ...       ...   ...          ...  ..  ..       ...       ...
# 49314   95000  0.632653  2022          신동아  12  10  0.066494  0.202899
# 49315  260000  0.489796  2022       대림아크로빌  12   9  0.400648  0.333333
# 49316  260000  0.489796  2022       대림아크로빌  12  15  0.389033  0.463768
# 49317   96500  0.408163  2022        대명비발디  12  17  0.158920  0.101449
# 49318  183000  0.265306  2022  도곡지웰카운티101동  12  17  0.230484  0.028986
#
#             계약일    선도50지수  ...  법정동_삼성동  법정동_세곡동  법정동_수서동  법정동_신사동  법정동_압구정동
# ...

# %%
X_train, X_test, y_train, y_test = get_x_y(bodong)
# Spot Check Algorithms
test_name = 'real estate'
main(X_train, X_test, y_train, y_test,test_name)
# Out:
# 1 result real estate predict result with using SVR
# 2 result real estate predict result with using SVR
# 3 result real estate predict result with using SVR
# r2:  0.7094
# MAE:  0.2339
# MSE:  0.1154
# RMSE:  0.3398
# SVR: 0.717267 (0.006352)
# 1 result real estate predict result with using KNN
# 2 result real estate predict result with using KNN
# 3 result real estate predict result with using KNN
# r2:  0.795
# MAE:  0.1848
# MSE:  0.0814
# RMSE:  0.2854
# KNN: 0.758347 (0.038238)
# /home/work/.local/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 1 result real estate predict result with using NN
# /home/work/.local/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
# ...

# %%
eco_bodong = onehotencoding(scaling(*bodong_merge_data(*economic_merge_data(df))))
eco_bodong
# Out:
# /home/work/mC2E2/datamining
# 기준금리_start
# 기준금리_end
# GDP_start
# GDP_end
# 선도50지수_start
# 선도50지수_end
# 전세가격지수_start
# 전세가격지수_end
# 매매가격지수_start
# 매매가격지수_end
#          거래금액      건축년도     년          아파트   월   일      전용면적         층
# 0       68000  0.163265  2012        역삼래미안   1   2  0.114745  0.115942  \
# 1       22950  0.224490  2012        대우디오빌   1   2  0.043496  0.275362
# 2       44500  0.183673  2012      브라운스톤역삼   1   4  0.116103  0.130435
# 3       99000  0.142857  2012       역삼푸르지오   1   7  0.176628  0.173913
# 4       49500  0.142857  2012     역삼디오슈페리움   1   7  0.175246  0.260870
# ...       ...       ...   ...          ...  ..  ..       ...       ...
# 49314   95000  0.632653  2022          신동아  12  10  0.066494  0.202899
# 49315  260000  0.489796  2022       대림아크로빌  12   9  0.400648  0.333333
# 49316  260000  0.489796  2022       대림아크로빌  12  15  0.389033  0.463768
# 49317   96500  0.408163  2022        대명비발디  12  17  0.158920  0.101449
# ...

# %% [markdown]
# # 부동산지수 + 경제요인 분석결과

# %%
X_train, X_test, y_train, y_test = get_x_y(eco_bodong)
# Spot Check Algorithms
test_name = 'real estate + economic'
main(X_train, X_test, y_train, y_test,test_name)
# Out:
# 1 result real estate + economic predict result with using SVR
# 2 result real estate + economic predict result with using SVR
# 3 result real estate + economic predict result with using SVR
# r2:  0.7204
# MAE:  0.2301
# MSE:  0.1111
# RMSE:  0.3333
# SVR: 0.728056 (0.006167)
# 1 result real estate + economic predict result with using KNN
# 2 result real estate + economic predict result with using KNN
# 3 result real estate + economic predict result with using KNN
# r2:  0.7527
# MAE:  0.2026
# MSE:  0.0982
# RMSE:  0.3134
# KNN: 0.701983 (0.047850)
# /home/work/.local/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 1 result real estate + economic predict result with using NN
# 2 result real estate + economic predict result with using NN
# ...

# %%
# ultra = onehotencoding(scaling(*bodong_merge_data(*social_merge_data(*economic_merge_data(df)))))
ultra = onehotencoding(scaling(*bodong_merge_data(*social_merge_data(*economic_merge_data(df)))))
ultra
# Out:
# /home/work/mC2E2/datamining
# 기준금리_start
# 기준금리_end
# GDP_start
# GDP_end
# 공원수_start
# 공원수_end
# 인구밀도_start
# 인구밀도_end
# 선도50지수_start
# 선도50지수_end
# 전세가격지수_start
# 전세가격지수_end
# 매매가격지수_start
# 매매가격지수_end
#          거래금액      건축년도     년          아파트   월   일      전용면적         층
# 0       68000  0.163265  2012        역삼래미안   1   2  0.114745  0.115942  \
# 1       22950  0.224490  2012        대우디오빌   1   2  0.043496  0.275362
# 2       44500  0.183673  2012      브라운스톤역삼   1   4  0.116103  0.130435
# 3       99000  0.142857  2012       역삼푸르지오   1   7  0.176628  0.173913
# 4       49500  0.142857  2012     역삼디오슈페리움   1   7  0.175246  0.260870
# ...       ...       ...   ...          ...  ..  ..       ...       ...
# 49314   95000  0.632653  2022          신동아  12  10  0.066494  0.202899
# 49315  260000  0.489796  2022       대림아크로빌  12   9  0.400648  0.333333
# 49316  260000  0.489796  2022       대림아크로빌  12  15  0.389033  0.463768
# ...

# %%
X_train, X_test, y_train, y_test = get_x_y(ultra)
# Spot Check Algorithms
test_name = 'ALL'
main(X_train, X_test, y_train, y_test,test_name)
# Out:
# 1 result ALL predict result with using SVR
# 2 result ALL predict result with using SVR
# 3 result ALL predict result with using SVR
# r2:  0.7205
# MAE:  0.231
# MSE:  0.1123
# RMSE:  0.3351
# SVR: 0.727919 (0.004872)
# 1 result ALL predict result with using KNN
# 2 result ALL predict result with using KNN
# 3 result ALL predict result with using KNN
# r2:  0.7621
# MAE:  0.2008
# MSE:  0.0956
# RMSE:  0.3092
# KNN: 0.704229 (0.054831)
# 1 result ALL predict result with using NN
# /home/work/.local/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 2 result ALL predict result with using NN
# /home/work/.local/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
# ...

# %%
tscv = TimeSeriesSplit(n_splits=3)
for i, (train_index, test_index) in enumerate(tscv.split(X_train)):
    print(len(train_index),len(test_index))
# Out:
# 9678 9676
# 19354 9676
# 29030 9676

# %%
total,_ = bodong_merge_data(*social_merge_data(*economic_merge_data(df)))
# Out:
# /home/work/mC2E2/datamining
# 기준금리_start
# 기준금리_end
# GDP_start
# GDP_end
# 공원수_start
# 공원수_end
# 인구밀도_start
# 인구밀도_end
# 선도50지수_start
# 선도50지수_end
# 전세가격지수_start
# 전세가격지수_end
# 매매가격지수_start
# 매매가격지수_end

# %%
import matplotlib.pyplot as plt
cor = total.drop(['계약일','년','월','일','법정동','아파트'],axis=1).corr()
# heatmap을 사용해 상관관계 테이블을 한눈에 보기 쉬운 형태로 만들어봅시다.

# %%
cor
# Out:
#                      거래금액      건축년도      전용면적         층      기준금리
# 거래금액             1.000000  0.144895  0.680444  0.226849 -0.353127  \
# 건축년도             0.144895  1.000000 -0.042281 -0.246373 -0.068204
# 전용면적             0.680444 -0.042281  1.000000  0.194089 -0.046089
# 층                0.226849 -0.246373  0.194089  1.000000 -0.042083
# 기준금리            -0.353127 -0.068204 -0.046089 -0.042083  1.000000
# 국내총생산(명목GDP)     0.462895  0.062627  0.056637  0.064200 -0.800798
# 경제성장률(실질GDP성장률) -0.167846 -0.049521 -0.005583 -0.018988  0.308655
# 공원수             -0.280968 -0.020800 -0.356640 -0.076435  0.024975
# 인구밀도             0.049456 -0.276243  0.189655  0.284519  0.031677
# 선도50지수           0.492825  0.068773  0.039448  0.073127 -0.644762
# 전년동월대비증감률        0.315751  0.032012  0.060647  0.044802 -0.773664
# 전세가격지수           0.386013  0.063918  0.050088  0.050333 -0.874860
# 매매가격지수           0.490982  0.070617  0.038556  0.072421 -0.644951
#
# ...

# %%
import seaborn as sns
plt.figure(figsize=(15, 7))
plt.title('아파트 매매 자료 상관분석', size = 20)
sns.heatmap(cor, cmap="Greens", annot=True, linewidths=0.5, fmt=".3f", cbar = True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 4
#       2 plt.figure(figsize=(15, 7))
#       3 plt.title('아파트 매매 자료 상관분석', size = 20)
# ----> 4 sns.heatmap(cor, cmap="Greens", annot=True, linewidths=0.5, fmt=".3f")
#       5 plt.show()
#
# File /usr/local/lib/python3.8/dist-packages/seaborn/matrix.py:510, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     331 """Plot rectangular data as a color-encoded matrix.
#     332
#     333 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     507
#     508 """
#     509 # Initialize the plotter object
# --> 510 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     511                       annot_kws, cbar, cbar_kws, xticklabels,
# ...
